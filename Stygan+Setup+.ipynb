# %% [markdown]
# ## Environement set up for Nvidia's StyleGAN
# > This is to set up  StyleGAN environment on Ubuntu 18.04 with anaconda
#
# * Both Linux and Windows are supported, but we strongly recommend Linux for performance and compatibility reasons.
# * 64-bit Python 3.6 installation. We recommend Anaconda3 with numpy 1.14.3 or newer.
# * TensorFlow 1.10.0 or newer with GPU support.
# *  One or more high-end NVIDIA GPUs with at least 11GB of DRAM. We recommend NVIDIA DGX-1 with 8 Tesla V100 GPUs.
# * NVIDIA driver 391.35 or newer, CUDA toolkit 9.0 or newer, cuDNN 7.3.1 or newer.
#
# This creates the environement used in this guide with anaconda.
#
# https://www.gwern.net/Faces

# %%
# !conda info
# Out:
# Current conda install:
#
#                platform : linux-64
#           conda version : 4.3.27
#        conda is private : False
#       conda-env version : 4.3.27
#     conda-build version : 3.0.23
#          python version : 3.6.2.final.0
#        requests version : 2.18.4
#        root environment : /home/flufylobster/anaconda3  (writable)
#     default environment : /home/flufylobster/anaconda3
#        envs directories : /home/flufylobster/anaconda3/envs
#                           /home/flufylobster/.conda/envs
#           package cache : /home/flufylobster/anaconda3/pkgs
#                           /home/flufylobster/.conda/pkgs
#            channel URLs : https://repo.continuum.io/pkgs/main/linux-64
#                           https://repo.continuum.io/pkgs/main/noarch
#                           https://repo.continuum.io/pkgs/free/linux-64
#                           https://repo.continuum.io/pkgs/free/noarch
# ...

# %% [markdown]
# ### Run code in terminal

# %% [markdown]
# ```conda create -n stylegan pip python=3.6```
#
# `source activate stylegan`
#
# `conda install tensorflow-gpu`
#
# `pip install pillow moviepy   lmdb `
#
# `pip install requests`
#
# `pip install opencv-contrib-python==4.0.0.21`

# %% [markdown]
# ## Test Tensorflow

# %%
python -c "import tensorflow as tf; tf.enable_eager_execution(); \
    print(tf.reduce_sum(tf.random_normal([1000, 1000])))"

# %% [markdown]
# ## downlaod stylegan Repo

# %% [markdown]
# `git clone 'https://github.com/NVlabs/stylegan.git' && cd ./stylegan/`

# %% [markdown]
# ### Test Style GAN

# %% [markdown]
# `python pretrained_example.py`

# %% [markdown]
# > If successful you should see this person that does not exist. in the results folder.
#
# >Below is a printout of the directory structure.

# %% [markdown]
# file:///home/flufylobster/stylegan/results/example.png![image.png](attachment:image.png)

# %% [markdown]
# ## Directory Structure

# %%
! tree
# Out:
# .
# ├── cache
# │   └── 263e666dc20e26dcbfa514733c1d1f81_karras2019stylegan-ffhq-1024x1024.pkl
# ├── config.py
# ├── dataset_tool.py
# ├── dnnlib
# │   ├── __init__.py
# │   ├── __pycache__
# │   │   ├── __init__.cpython-36.pyc
# │   │   └── util.cpython-36.pyc
# │   ├── submission
# │   │   ├── __init__.py
# │   │   ├── _internal
# │   │   │   └── run.py
# │   │   ├── __pycache__
# │   │   │   ├── __init__.cpython-36.pyc
# │   │   │   ├── run_context.cpython-36.pyc
# │   │   │   └── submit.cpython-36.pyc
# │   │   ├── run_context.py
# │   │   └── submit.py
# │   ├── tflib
# │   │   ├── autosummary.py
# │   │   ├── __init__.py
# │   │   ├── network.py
# │   │   ├── optimizer.py
# │   │   ├── __pycache__
# │   │   │   ├── autosummary.cpython-36.pyc
# │   │   │   ├── __init__.cpython-36.pyc
# │   │   │   ├── network.cpython-36.pyc
# │   │   │   ├── optimizer.cpython-36.pyc
# │   │   │   └── tfutil.cpython-36.pyc
# │   │   └── tfutil.py
# │   └── util.py
# ├── generate_figures.py
# ...
